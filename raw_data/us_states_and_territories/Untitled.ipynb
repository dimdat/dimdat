# %%
import json
import pandas as pd
import os
import shutil

def rebuild_folder(dataset_dir):
    # delete and rebuild dataset directory
    if os.path.exists(dataset_dir):
        shutil.rmtree(dataset_dir)
    os.makedirs(dataset_dir)

def write_csv(cols, dataset_dir):
    # header only needs to exist for multi column datasets
    write_header = len(cols) > 1
    subset = df.filter(cols, axis=1)
    subset.to_csv('{}data.csv'.format(dataset_dir), index=False, header=write_header)

def write_metadata(build, dataset_metadata, cols, dataset_dir):
    build['columns_metadata'] = [dataset_metadata[col] for col in cols]
    with open('{}metadata.json'.format(dataset_dir), 'w') as fp:
        json.dump(build, fp)

def main():
    df = pd.read_csv('data.csv')
    with open('builddata.json') as fp:
        builddata = json.load(fp)
    with open('metadata.json') as fp:
        dataset_metadata = json.load(fp)
    for build in builddata:
        dataset_dir = '{}/datasets/{}/'.format(os.path.dirname(os.path.dirname(os.getcwd())), build['route'])
        rebuild_folder(dataset_dir)
        cols = build['columns']
        write_csv(cols, dataset_dir)
        write_metadata(build, dataset_metadata, cols, dataset_dir)

if __name__ == "__main__":
    main()

# %%
df[(df['is_state']==1) | (df['is_territory'] == 1)]
# Out:
#                         name                     category  is_commonwealth  \
# 0                    Alabama                        State                0
# 1                     Alaska                        State                0
# 2                    Arizona                        State                0
# 3                   Arkansas                        State                0
# 4                 California                        State                0
# 5                   Colorado                        State                0
# 6                Connecticut                        State                0
# 7                   Delaware                        State                0
# 9                    Florida                        State                0
# 10                   Georgia                        State                0
# 11                    Hawaii                        State                0
# 12                     Idaho                        State                0
# 13                  Illinois                        State                0
# 14                   Indiana                        State                0
# 15                      Iowa                        State                0
# 16                    Kansas                        State                0
# 17                  Kentucky         State (Commonwealth)                1
# 18                 Louisiana                        State                0
# 19                     Maine                        State                0
# 20                  Maryland                        State                0
# 21             Massachusetts         State (Commonwealth)                1
# 22                  Michigan                        State                0
# 23                 Minnesota                        State                0
# 24               Mississippi                        State                0
# 25                  Missouri                        State                0
# 26                   Montana                        State                0
# 27                  Nebraska                        State                0
# 28                    Nevada                        State                0
# 29             New Hampshire                        State                0
# 30                New Jersey                        State                0
# 31                New Mexico                        State                0
# 32                  New York                        State                0
# 33            North Carolina                        State                0
# 34              North Dakota                        State                0
# 35                      Ohio                        State                0
# 36                  Oklahoma                        State                0
# 37                    Oregon                        State                0
# 38              Pennsylvania         State (Commonwealth)                1
# 39              Rhode Island                        State                0
# 40            South Carolina                        State                0
# 41              South Dakota                        State                0
# 42                 Tennessee                        State                0
# 43                     Texas                        State                0
# 44                      Utah                        State                0
# 45                   Vermont                        State                0
# 46                  Virginia         State (Commonwealth)                1
# 47                Washington                        State                0
# 48             West Virginia                        State                0
# 49                 Wisconsin                        State                0
# 50                   Wyoming                        State                0
# 51            American Samoa     Insular area (Territory)                0
# 52                      Guam     Insular area (Territory)                0
# 53  Northern Mariana Islands  Insular area (Commonwealth)                0
# 54               Puerto Rico     Insular area (Territory)                0
# 55       U.S. Virgin Islands     Insular area (Territory)                0
#
#     is_state  is_territory  is_federal_district          iso_3166  \
# 0          1             0                    0             US-AL
# 1          1             0                    0             US-AK
# 2          1             0                    0             US-AZ
# 3          1             0                    0             US-AR
# 4          1             0                    0             US-CA
# 5          1             0                    0             US-CO
# 6          1             0                    0             US-CT
# 7          1             0                    0             US-DE
# 9          1             0                    0             US-FL
# 10         1             0                    0             US-GA
# 11         1             0                    0             US-HI
# 12         1             0                    0             US-ID
# 13         1             0                    0             US-IL
# 14         1             0                    0             US-IN
# 15         1             0                    0             US-IA
# 16         1             0                    0             US-KS
# 17         1             0                    0             US-KY
# 18         1             0                    0             US-LA
# 19         1             0                    0             US-ME
# 20         1             0                    0             US-MD
# 21         1             0                    0             US-MA
# 22         1             0                    0             US-MI
# 23         1             0                    0             US-MN
# 24         1             0                    0             US-MS
# 25         1             0                    0             US-MO
# 26         1             0                    0             US-MT
# 27         1             0                    0             US-NE
# 28         1             0                    0             US-NV
# 29         1             0                    0             US-NH
# 30         1             0                    0             US-NJ
# 31         1             0                    0             US-NM
# 32         1             0                    0             US-NY
# 33         1             0                    0             US-NC
# 34         1             0                    0             US-ND
# 35         1             0                    0             US-OH
# 36         1             0                    0             US-OK
# 37         1             0                    0             US-OR
# 38         1             0                    0             US-PA
# 39         1             0                    0             US-RI
# 40         1             0                    0             US-SC
# 41         1             0                    0             US-SD
# 42         1             0                    0             US-TN
# 43         1             0                    0             US-TX
# 44         1             0                    0             US-UT
# 45         1             0                    0             US-VT
# 46         1             0                    0             US-VA
# 47         1             0                    0             US-WA
# 48         1             0                    0             US-WV
# 49         1             0                    0             US-WI
# 50         1             0                    0             US-WY
# 51         0             1                    0  AS ASM 016 US-AS
# 52         0             1                    0  GU GUM 316 US-GU
# 53         1             1                    0  MP MNP 580 US-MP
# 54         0             1                    0  PR PRI 630 US-PR
# 55         0             1                    0  VI VIR 850 US-VI
#
#    ansi_alphabetic_code  ansi_numeric_code usps_code       ...        \
# 0                    AL                  1        AL       ...
# 1                    AK                  2        AK       ...
# 2                    AZ                  4        AZ       ...
# 3                    AR                  5        AR       ...
# 4                    CA                  6        CA       ...
# 5                    CO                  8        CO       ...
# 6                    CT                  9        CT       ...
# 7                    DE                 10        DE       ...
# 9                    FL                 12        FL       ...
# 10                   GA                 13        GA       ...
# 11                   HI                 15        HI       ...
# 12                   ID                 16        ID       ...
# 13                   IL                 17        IL       ...
# 14                   IN                 18        IN       ...
# 15                   IA                 19        IA       ...
# 16                   KS                 20        KS       ...
# 17                   KY                 21        KY       ...
# 18                   LA                 22        LA       ...
# 19                   ME                 23        ME       ...
# 20                   MD                 24        MD       ...
# 21                   MA                 25        MA       ...
# 22                   MI                 26        MI       ...
# 23                   MN                 27        MN       ...
# 24                   MS                 28        MS       ...
# 25                   MO                 29        MO       ...
# 26                   MT                 30        MT       ...
# 27                   NE                 31        NE       ...
# 28                   NV                 32        NV       ...
# 29                   NH                 33        NH       ...
# 30                   NJ                 34        NJ       ...
# 31                   NM                 35        NM       ...
# 32                   NY                 36        NY       ...
# 33                   NC                 37        NC       ...
# 34                   ND                 38        ND       ...
# 35                   OH                 39        OH       ...
# 36                   OK                 40        OK       ...
# 37                   OR                 41        OR       ...
# 38                   PA                 42        PA       ...
# 39                   RI                 44        RI       ...
# 40                   SC                 45        SC       ...
# 41                   SD                 46        SD       ...
# 42                   TN                 47        TN       ...
# 43                   TX                 48        TX       ...
# 44                   UT                 49        UT       ...
# 45                   VT                 50        VT       ...
# 46                   VA                 51        VA       ...
# 47                   WA                 53        WA       ...
# 48                   WV                 54        WV       ...
# 49                   WI                 55        WI       ...
# 50                   WY                 56        WY       ...
# 51                   AS                 60        AS       ...
# 52                   GU                 66        GU       ...
# 53                   MP                 69        MP       ...
# 54                   PR                 72        PR       ...
# 55                   VI                 78        VI       ...
#
#    acquired_date established_date  population  total_square_miles  \
# 0            NaN     Dec 14, 1819   4,874,747              52,420
# 1            NaN      Jan 3, 1959     739,795             665,384
# 2            NaN     Feb 14, 1912   7,016,270             113,990
# 3            NaN     Jun 15, 1836   3,004,279              53,179
# 4            NaN      Sep 9, 1850  39,536,653             163,695
# 5            NaN      Aug 1, 1876   5,607,154             104,094
# 6            NaN      Jan 9, 1788   3,588,184               5,543
# 7            NaN      Dec 7, 1787     961,939               2,489
# 9            NaN      Mar 3, 1845  20,984,400              65,758
# 10           NaN      Jan 2, 1788  10,429,379              59,425
# 11           NaN     Aug 21, 1959   1,427,538              10,932
# 12           NaN      Jul 3, 1890   1,716,943              83,569
# 13           NaN      Dec 3, 1818  12,802,023              57,914
# 14           NaN     Dec 11, 1816   6,666,818              36,420
# 15           NaN     Dec 28, 1846   3,145,711              56,273
# 16           NaN     Jan 29, 1861   2,913,123              82,278
# 17           NaN      Jun 1, 1792   4,454,189              40,408
# 18           NaN     Apr 30, 1812   4,684,333              52,378
# 19           NaN     Mar 15, 1820   1,335,907              35,380
# 20           NaN     Apr 28, 1788   6,052,177              12,406
# 21           NaN      Feb 6, 1788   6,859,819              10,554
# 22           NaN     Jan 26, 1837   9,962,311              96,714
# 23           NaN     May 11, 1858   5,576,606              86,936
# 24           NaN     Dec 10, 1817   2,984,100              48,432
# 25           NaN     Aug 10, 1821   6,113,532              69,707
# 26           NaN      Nov 8, 1889   1,050,493             147,040
# 27           NaN      Mar 1, 1867   1,920,076              77,348
# 28           NaN     Oct 31, 1864   2,998,039             110,572
# 29           NaN     Jun 21, 1788   1,342,795               9,349
# 30           NaN     Dec 18, 1787   9,005,644               8,723
# 31           NaN      Jan 6, 1912   2,088,070             121,590
# 32           NaN     Jul 26, 1788  19,849,399              54,555
# 33           NaN     Nov 21, 1789  10,273,419              53,819
# 34           NaN      Nov 2, 1889     755,393              70,698
# 35           NaN      Mar 1, 1803  11,658,609              44,826
# 36           NaN     Nov 16, 1907   3,930,864              69,899
# 37           NaN     Feb 14, 1859   4,142,776              98,379
# 38           NaN     Dec 12, 1787  12,805,537              46,054
# 39           NaN     May 29, 1790   1,059,639               1,545
# 40           NaN     May 23, 1788   5,024,369              32,020
# 41           NaN      Nov 2, 1889     869,666              77,116
# 42           NaN      Jun 1, 1796   6,715,984              42,144
# 43           NaN     Dec 29, 1845  28,304,596             268,596
# 44           NaN      Jan 4, 1896   3,101,833              84,897
# 45           NaN      Mar 4, 1791     623,657               9,616
# 46           NaN     Jun 25, 1788   8,470,020              42,775
# 47           NaN     Nov 11, 1889   7,405,743              71,298
# 48           NaN     Jun 20, 1863   1,815,857              24,230
# 49           NaN     May 29, 1848   5,795,483              65,496
# 50           NaN     Jul 10, 1890     579,315              97,813
# 51        1900.0              NaN      57,400                 581
# 52        1899.0              NaN     161,700                 571
# 53        1986.0              NaN      52,300               1,976
# 54        1899.0              NaN   3,337,177               5,325
# 55        1917.0              NaN     103,700                 733
#
#     total_square_kilometers land_square_miles land_square_kilometers  \
# 0                   135,767            50,645                131,171
# 1                 1,723,337           570,641              1,477,953
# 2                   295,234           113,594                294,207
# 3                   137,732            52,035                134,771
# 4                   423,967           155,779                403,466
# 5                   269,601           103,642                268,431
# 6                    14,357             4,842                 12,542
# 7                     6,446             1,949                  5,047
# 9                   170,312            53,625                138,887
# 10                  153,910            57,513                148,959
# 11                   28,313             6,423                 16,635
# 12                  216,443            82,643                214,045
# 13                  149,995            55,519                143,793
# 14                   94,326            35,826                 92,789
# 15                  145,746            55,857                144,669
# 16                  213,100            81,759                211,754
# 17                  104,656            39,486                102,269
# 18                  135,659            43,204                111,898
# 19                   91,633            30,843                 79,883
# 20                   32,131             9,707                 25,142
# 21                   27,336             7,800                 20,202
# 22                  250,487            56,539                146,435
# 23                  225,163            79,627                206,232
# 24                  125,438            46,923                121,531
# 25                  180,540            68,742                178,040
# 26                  380,831           145,546                376,962
# 27                  200,330            76,824                198,974
# 28                  286,380           109,781                284,332
# 29                   24,214             8,953                 23,187
# 30                   22,591             7,354                 19,047
# 31                  314,917           121,298                314,161
# 32                  141,297            47,126                122,057
# 33                  139,391            48,618                125,920
# 34                  183,108            69,001                178,711
# 35                  116,098            40,861                105,829
# 36                  181,037            68,595                177,660
# 37                  254,799            95,988                248,608
# 38                  119,280            44,743                115,883
# 39                    4,001             1,034                  2,678
# 40                   82,933            30,061                 77,857
# 41                  199,729            75,811                196,350
# 42                  109,153            41,235                106,798
# 43                  695,662           261,232                676,587
# 44                  219,882            82,170                212,818
# 45                   24,906             9,217                 23,871
# 46                  110,787            39,490                102,279
# 47                  184,661            66,456                172,119
# 48                   62,756            24,038                 62,259
# 49                  169,635            54,158                140,268
# 50                  253,335            97,093                251,470
# 51                    1,505                76                    198
# 52                    1,478               210                    543
# 53                    5,117               182                    472
# 54                   13,791             3,424                  8,868
# 55                    1,898               134                    348
#
#     water_square_miles water_square_kilometers representatives
# 0                1,775                   4,597               7
# 1               94,743                 245,384               1
# 2                  396                   1,026               9
# 3                1,143                   2,961               4
# 4                7,916                  20,501              53
# 5                  452                   1,170               7
# 6                  701                   1,816               5
# 7                  540                   1,399               1
# 9               12,133                  31,424              27
# 10               1,912                   4,951              14
# 11               4,509                  11,678               2
# 12                 926                   2,398               2
# 13               2,395                   6,202              18
# 14                 593                   1,537               9
# 15                 416                   1,077               4
# 16                 520                   1,346               4
# 17                 921                   2,387               6
# 18               9,174                  23,761               6
# 19               4,537                  11,750               2
# 20               2,699                   6,990               8
# 21               2,754                   7,134               9
# 22              40,175                 104,052              14
# 23               7,309                  18,930               8
# 24               1,508                   3,907               4
# 25                 965                   2,501               8
# 26               1,494                   3,869               1
# 27                 524                   1,356               3
# 28                 791                   2,048               4
# 29                 397                   1,027               2
# 30               1,368                   3,544              12
# 31                 292                     757               3
# 32               7,429                  19,240              27
# 33               5,201                  13,471              13
# 34               1,698                   4,397               1
# 35               3,965                  10,269              16
# 36               1,304                   3,377               5
# 37               2,391                   6,191               5
# 38               1,312                   3,397              18
# 39                 511                   1,324               2
# 40               1,960                   5,076               7
# 41               1,305                   3,379               1
# 42                 909                   2,355               9
# 43               7,365                  19,075              36
# 44               2,727                   7,064               4
# 45                 400                   1,035               1
# 46               3,285                   8,508              11
# 47               4,842                  12,542              10
# 48                 192                     497               3
# 49              11,339                  29,367               8
# 50                 720                   1,864               1
# 51                 505                   1,307               1
# 52                 361                     935               1
# 53               1,793                   4,644               1
# 54               1,901                   4,924               1
# 55                 599                   1,550               1
#
# [55 rows x 27 columns]
